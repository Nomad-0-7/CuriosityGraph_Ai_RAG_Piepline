# %% [markdown]
# <a href="https://colab.research.google.com/github/Nomad-0-7/CuriosityGraph_Ai_RAG_Piepline/blob/main/CuriosityGraph_Ai_RAG_Piepline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install arxiv   # Or `uv add arxiv` or similar.
# Out:
# Collecting arxiv
#   Downloading arxiv-4.0.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: lxml<7.0,>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from arxiv) (6.1.1)
# Requirement already satisfied: requests<2.34,>=2.32 in /usr/local/lib/python3.12/dist-packages (from arxiv) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<2.34,>=2.32->arxiv) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<2.34,>=2.32->arxiv) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<2.34,>=2.32->arxiv) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<2.34,>=2.32->arxiv) (2026.5.20)
# Downloading arxiv-4.0.0-py3-none-any.whl (13 kB)
# Installing collected packages: arxiv
# Successfully installed arxiv-4.0.0

# %%
import arxiv
from urllib.request import urlretrieve
import pandas as pd
import os
import re

client = arxiv.Client()

search = arxiv.Search(
    query = 'AI Engineering',
    max_results = 20,
    sort_by = arxiv.SortCriterion.SubmittedDate,
    sort_order = arxiv.SortOrder.Descending
)
results = client.results(search)

data = [
      {
          "title": r.title,
          "pdf_url": r.pdf_url,
          "published": r.published
      }
      for r in client.results(search)
]
df = pd.DataFrame(data)

pd.set_option('display.max_colwidth', None)

print(df["title"])

download_dir = "./knowledge_base"
os.makedirs(download_dir, exist_ok=True)

print("--- Starting Downloads ---")
for index, row in df.iterrows():
    title = row["title"]
    url = row["pdf_url"]
    clean_title = re.sub(r'[^a-zA-Z0-9\s_-]', '', title).strip()
    clean_title = re.sub(r'\s+', ' ', clean_title)
    filename = f"{clean_title}.pdf"
    file_path = os.path.join(download_dir, filename)
    print(f"[{index + 1}/{len(df)}] Downloading: {title}")
    try:
        urlretrieve(url, file_path)
        print(f"✓ Saved to: {file_path}\n")
    except Exception as e:
        print(f"✗ Failed to download: {e}\n")
print("--- Data Ingestion Complete ---")
# Out:
# 0                                                                                                    Reinforcement Learning without Ground-Truth Solutions can Improve LLMs
# 1                                                                     CHIA: An open-source framework for principled, agentic AI-driven hardware/software co-design research
# 2                                                                                              Jet impingement cooling with multi-stage ducted electroaerodynamic actuators
# 3     A Multi-Fidelity Convolutional Autoencoder-Transfer Learning Framework for Guided-Wave-Based Damage Diagnosis Using Large Simulated and Limited Experimental Datasets
# 4                                                                     AI Healthcare Chatbots as Information Infrastructure: A Large-Scale Study of User-Reported Breakdowns
# 5                                                                                                                        Generative Models on Analog Hardware with Dynamics
# 6                                                                    Designing Reward Signals for Portable Query Generation: A Case Study in Industrial Semantic Job Search
# 7                                                                                                    Large-scale multimode entangling-gate synthesis in trapped-ion systems
# 8                                                                                      Conjecture About Arbitrary Even-Order Convexity of $w$-Optimization of the Split CIF
# 9                                                                                                                                                            Beyond Objects
# 10                                                                                      Resilient Output Containment under Undisclosed Leader Dynamics and Actuator Attacks
# 11                                                                                   Advancing Omnimodal Embodied Agents from Isolated Skills to Everyday Physical Autonomy
# 12                                                                    NOVA: A Verification-Aware Agent Harness for Architecture Evolution in Industrial Recommender Systems
# 13                                                          From Celebrities to Anyone: Characterizing AI Nudification Content, Technology, and Community Dynamics on 4chan
# 14                                                                 Bridging Talk and Thought: Understanding Dialogue Dynamics Across Collaborative Problem-Solving Contexts
# 15                                                                            Smaller Models, Unexpected Costs: Trade-offs in LLM Quantization for Automated Program Repair
# 16                                                                      A Process Harness for Uplifting Legacy Workflows to Agentic BPM: Design and Realization in CUGA FLO
# 17                                                      From Approximate Floquet Engineering to Full Floquet Theory: Coherent Control of Chiral Spin Systems in Spintronics
# 18                                                                      A hybrid IFENN solver for generalizable modeling of phase-field fracture initiation and propagation
# 19                                                                         Learning to Fold: prizewinning solution at LeHome Challenge 2026 (1st place online, 2nd offline)
# Name: title, dtype: object
# --- Starting Downloads ---
# [1/20] Downloading: Reinforcement Learning without Ground-Truth Solutions can Improve LLMs
# ✓ Saved to: ./knowledge_base/Reinforcement Learning without Ground-Truth Solutions can Improve LLMs.pdf
#
# [2/20] Downloading: CHIA: An open-source framework for principled, agentic AI-driven hardware/software co-design research
# ✓ Saved to: ./knowledge_base/CHIA An open-source framework for principled agentic AI-driven hardwaresoftware co-design research.pdf
#
# [3/20] Downloading: Jet impingement cooling with multi-stage ducted electroaerodynamic actuators
# ✓ Saved to: ./knowledge_base/Jet impingement cooling with multi-stage ducted electroaerodynamic actuators.pdf
#
# [4/20] Downloading: A Multi-Fidelity Convolutional Autoencoder-Transfer Learning Framework for Guided-Wave-Based Damage Diagnosis Using Large Simulated and Limited Experimental Datasets
# ✓ Saved to: ./knowledge_base/A Multi-Fidelity Convolutional Autoencoder-Transfer Learning Framework for Guided-Wave-Based Damage Diagnosis Using Large Simulated and Limited Experimental Datasets.pdf
#
# [5/20] Downloading: AI Healthcare Chatbots as Information Infrastructure: A Large-Scale Study of User-Reported Breakdowns
# ✓ Saved to: ./knowledge_base/AI Healthcare Chatbots as Information Infrastructure A Large-Scale Study of User-Reported Breakdowns.pdf
#
# [6/20] Downloading: Generative Models on Analog Hardware with Dynamics
# ✓ Saved to: ./knowledge_base/Generative Models on Analog Hardware with Dynamics.pdf
#
# [7/20] Downloading: Designing Reward Signals for Portable Query Generation: A Case Study in Industrial Semantic Job Search
# ✓ Saved to: ./knowledge_base/Designing Reward Signals for Portable Query Generation A Case Study in Industrial Semantic Job Search.pdf
#
# [8/20] Downloading: Large-scale multimode entangling-gate synthesis in trapped-ion systems
# ✓ Saved to: ./knowledge_base/Large-scale multimode entangling-gate synthesis in trapped-ion systems.pdf
#
# [9/20] Downloading: Conjecture About Arbitrary Even-Order Convexity of $w$-Optimization of the Split CIF
# ✓ Saved to: ./knowledge_base/Conjecture About Arbitrary Even-Order Convexity of w-Optimization of the Split CIF.pdf
#
# [10/20] Downloading: Beyond Objects
# ✓ Saved to: ./knowledge_base/Beyond Objects.pdf
#
# [11/20] Downloading: Resilient Output Containment under Undisclosed Leader Dynamics and Actuator Attacks
# ✓ Saved to: ./knowledge_base/Resilient Output Containment under Undisclosed Leader Dynamics and Actuator Attacks.pdf
#
# [12/20] Downloading: Advancing Omnimodal Embodied Agents from Isolated Skills to Everyday Physical Autonomy
# ✓ Saved to: ./knowledge_base/Advancing Omnimodal Embodied Agents from Isolated Skills to Everyday Physical Autonomy.pdf
#
# [13/20] Downloading: NOVA: A Verification-Aware Agent Harness for Architecture Evolution in Industrial Recommender Systems
# ✓ Saved to: ./knowledge_base/NOVA A Verification-Aware Agent Harness for Architecture Evolution in Industrial Recommender Systems.pdf
#
# [14/20] Downloading: From Celebrities to Anyone: Characterizing AI Nudification Content, Technology, and Community Dynamics on 4chan
# ✓ Saved to: ./knowledge_base/From Celebrities to Anyone Characterizing AI Nudification Content Technology and Community Dynamics on 4chan.pdf
#
# [15/20] Downloading: Bridging Talk and Thought: Understanding Dialogue Dynamics Across Collaborative Problem-Solving Contexts
# ✓ Saved to: ./knowledge_base/Bridging Talk and Thought Understanding Dialogue Dynamics Across Collaborative Problem-Solving Contexts.pdf
#
# [16/20] Downloading: Smaller Models, Unexpected Costs: Trade-offs in LLM Quantization for Automated Program Repair
# ✓ Saved to: ./knowledge_base/Smaller Models Unexpected Costs Trade-offs in LLM Quantization for Automated Program Repair.pdf
#
# [17/20] Downloading: A Process Harness for Uplifting Legacy Workflows to Agentic BPM: Design and Realization in CUGA FLO
# ✓ Saved to: ./knowledge_base/A Process Harness for Uplifting Legacy Workflows to Agentic BPM Design and Realization in CUGA FLO.pdf
#
# [18/20] Downloading: From Approximate Floquet Engineering to Full Floquet Theory: Coherent Control of Chiral Spin Systems in Spintronics
# ✓ Saved to: ./knowledge_base/From Approximate Floquet Engineering to Full Floquet Theory Coherent Control of Chiral Spin Systems in Spintronics.pdf
#
# [19/20] Downloading: A hybrid IFENN solver for generalizable modeling of phase-field fracture initiation and propagation
# ✓ Saved to: ./knowledge_base/A hybrid IFENN solver for generalizable modeling of phase-field fracture initiation and propagation.pdf
#
# [20/20] Downloading: Learning to Fold: prizewinning solution at LeHome Challenge 2026 (1st place online, 2nd offline)
# ✓ Saved to: ./knowledge_base/Learning to Fold prizewinning solution at LeHome Challenge 2026 1st place online 2nd offline.pdf
#
# --- Data Ingestion Complete ---
